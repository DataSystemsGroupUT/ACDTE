# %%
# %tensorflow_version 1.x

# %%
import numpy as np
import pandas as pd
import sklearn
import sklearn.metrics
from sklearn import tree
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

import torch
from torch.autograd import Variable as V
import torchvision.models as models
from torchvision import transforms as trn
from torch.nn import functional as F
import torch.nn as nn
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = np.array(classes)

# %%
arch = 'resnet50'
model_file = f'{arch}_places365.pth.tar'
if not os.access(model_file, os.W_OK):
    weight_url = 'http://places2.csail.mit.edu/models_places365/' + model_file
    os.system('wget ' + weight_url)

model = models.__dict__[arch](num_classes=365)
checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
model.eval()
for param in model.parameters():
    param.requires_grad = False
'convert model to evaluation mode with no grad'
# Out:
# 'convert model to evaluation mode with no grad'

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
feature_extractor = nn.Sequential(*list(model.children())[:-2], nn.AdaptiveAvgPool2d(1)).eval().to(device)

# %%
# !cp drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/resized_imgs.pkl  /content/
# !cp drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/masks.pkl  /content/
# !cp drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/classes.pkl  /content/

# %%
import pickle
with open('masks.pkl', 'rb') as f:
  masks = pickle.load(f)
with open('resized_imgs.pkl', 'rb') as f:
  imgs = pickle.load(f)
with open('classes.pkl', 'rb') as f:
  labels = np.array(pickle.load(f))

# %%
def get_segments(img, mask, threshold = 0.05):
  ade_classes = pd.read_csv('https://raw.githubusercontent.com/CSAILVision/sceneparsing/master/objectInfo150.csv')
  segs = np.unique(mask)
  segments = []
  total = mask.shape[0]*mask.shape[1]
  segments_classes = []
  for seg in segs:
    idxs = mask==seg
    sz = np.sum(idxs)
    if sz < threshold*total:
      continue
    segment = img*idxs[..., None]
    w, h, _ = np.nonzero(segment)
    segment = segment[np.min(w):np.max(w),np.min(h):np.max(h),:]
    segments.append(segment)
    segments_classes.append(ade_classes['Name'].loc[ade_classes['Idx']==seg].iloc[0])
  return segments, segments_classes

# %%
img_segments = []
img_segments_classes = []
for img, msk in zip(imgs, masks):
  segss, seg_class = get_segments(np.array(img), msk, threshold = 0.005)
  img_segments_classes.append(seg_class)
  img_segments.append(segss)

# %%
centre_crop = trn.Compose([
        trn.Resize((256,256)),
        trn.CenterCrop(224),
        trn.ToTensor(),
        # trn.Normalize([0, 0, 0], [255, 255, 225]),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
outputs = []
def hook(module, input, output):
    x = nn.AdaptiveAvgPool2d(1)(output)
    outputs.append(x.cpu().numpy().squeeze())
full_model = model
handle = full_model.layer4[2].register_forward_hook(hook)
full_model.to(device)
'finished the full model with hook attached'
# Out:
# 'finished the full model with hook attached'

# %%
chosen_classes = ['street', 'bedroom', 'living_room', 'bathroom', 'kitchen', 
            'skyscraper', 'highway', 'conference_room', 'mountain_snowy', 'office',
            'corridor', 'airport_terminal', 'attic', 'mountain', 'park', 'coast', 
            'alley','beach', 'childs_room', 'art_gallery','castle', 'dorm_room', 
            'nursery', 'lobby', 'reception', 'bar', 'house', 'bridge', 'classroom']
num_classes = len(chosen_classes)
idxs = []
c = 0
for ccls in chosen_classes:
  idx = np.argwhere(classes == ccls)
  if len(idx) == 0:
    print(f'class {ccls} is not found in places365, so we will use places365 alternate')
    c+=1
  else:
    idxs.append(idx[0][0])

# %%
idxs = []
c = 0
for ccls in chosen_classes:
  idx = np.argwhere(classes == ccls)
  if len(idx) == 0:
    print(f'class {ccls} is not found in places365, so we will use places365 alternate')
    c+=1
  else:
    idxs.append(idx[0][0])

# %%
del outputs
outputs = []
y_model = []
for img in imgs:
  input_img = V(centre_crop(img).unsqueeze(0))
  input_img = input_img.to(device)
  pred = full_model.forward(input_img)
  y_model.append(classes[idxs][np.argmax((pred.cpu().detach().numpy()[:,idxs]))])
outputs = np.array(outputs)
img_vectors = np.copy(outputs)

# %%
del outputs
outputs = []
img_segmentsid = []
segments_classes = []
for i, img_seg in enumerate(img_segments):
    img_segmentsid.append((img_segmentsid[-1] if i>0 else 0) + len(img_seg))
    for seg in img_seg:
      img = Image.fromarray(seg, 'RGB')
      input_img = V(centre_crop(img).unsqueeze(0))
      input_img = input_img.to(device)
      pred = full_model.forward(input_img)
      segments_classes.append(classes[idxs][np.argmax((pred.cpu().detach().numpy()[:,idxs]))])
outputs = np.array(outputs)
all_vectors = np.copy(outputs)

# %%
feature_vectors = []
for i in range(len(img_segmentsid)):
  feature_vectors.append(all_vectors[(img_segmentsid[i-1] if i>0 else 0):img_segmentsid[i]])

# %%
segment_img = {}
c = 0
for j, fvec in enumerate(feature_vectors): 
  c_old = c
  c += len(fvec) if len(fvec) != 1024 else 1
  for i in range(c_old, c):
    segment_img[i] = j

# %%
import sklearn.metrics
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def cluster_top_k(cluster_id, k = 40):
  instances_ids = np.argwhere(clusters_labels==cluster_id).squeeze()
  instances = X[instances_ids]
  scores = []
  for inst in instances:
    scores.append(-kmeans.score([inst]))
  final_ids = np.argsort(scores)[:k]
  return instances_ids[final_ids]

cluster_instances_id = lambda cid:  np.argwhere(clusters_labels==cid).squeeze()

def is_single_img_clusters(cls_id):
  instances_ids = cluster_instances_id(cls_id)
  # instances_ids = cluster_representatives[cls_id]
  source_imgs = [segment_img[inst_id] for inst_id in instances_ids]
  unique_imgs = len(np.unique(source_imgs))
  return 0 if unique_imgs > 1 else 1

# %%
img_distances = sklearn.metrics.pairwise.euclidean_distances(img_vectors)

# %%
num_neighbors = 300
depths = [5, 10, 15, 20]
train_accuracy = {}
test_accuracy = {}
train_f1 = {}
test_f1 = {}
hit = {}
for i in depths:
  train_accuracy[i] = []
  test_accuracy[i] = []
  train_f1[i] = []
  test_f1[i] = []
  hit[i] = []
for instance_id in range(500):
  neighbors = np.argsort(img_distances[instance_id])[:num_neighbors]
  neighbor_vectors = img_vectors[neighbors]
  neighbor_labels = np.array(y_model)[neighbors]
  print('clustering the neighbor dataset ................')
  X = np.array([v for i in neighbors for v in feature_vectors[i]])
  num_segs = X.shape[0]
  k = int(num_segs**0.5)
  kmeans = KMeans(n_clusters=k, random_state=0).fit(X)
  clusters_labels = kmeans.labels_
  print('\ndone')

  cluster_names, cluster_counts = np.unique(clusters_labels, return_counts=1)
  print('removing small clusters  ................')
  count_threshold = int(k*0.6)
  ids = cluster_counts > count_threshold
  good_clusters = cluster_names[ids]
  cluster_counts = cluster_counts[ids]
  print(f'\ntotal number of clusters {len(cluster_names)}')
  print(f'total number of good clusters is {len(good_clusters)}')
  print('\ndone')

  print('removing single image clusters ............')
  final_clusters = []
  for j, cluster_id in enumerate(good_clusters):
    if is_single_img_clusters(cluster_id):
      continue
    final_clusters.append(cluster_id)
  final_clusters = np.array(final_clusters)
  print('\ndone')

  print('building linear models for each concept/cluster ............')
  linear_models = {}
  model_score = {}
  for cluster in final_clusters:
    positive_instances = cluster_instances_id(cluster)
    negative_instances = np.argwhere(clusters_labels!=cluster).squeeze()
    num_samples = min(len(positive_instances), len(negative_instances))
    selected_pos = np.random.choice(positive_instances, num_samples, replace=False)
    selected_neg = np.random.choice(negative_instances, num_samples, replace=False)
    train_x = np.append(X[selected_pos], X[selected_neg], axis=0)
    train_y = np.array([1] * num_samples + [0] * num_samples)
    train_x, val_x, train_y, val_y = train_test_split(train_x, train_y)
    n_components = min(256, len(train_x))
    pca_model = PCA(n_components=n_components)
    lr_model = LogisticRegression()
    pca_lr_model = Pipeline(steps = [('pca', pca_model), ('lr', lr_model)])
    pca_lr_model.fit(train_x, train_y)
    linear_models[cluster] = pca_lr_model
    model_score[cluster] = pca_lr_model.score(val_x, val_y)
  print('\ndone')

  print('removing low scoring clusters based on holdout accuracy ...............\n')
  c = 0
  for k, v in list(model_score.items()):
    if v < 0.75:
      c+=1
      print(f'removed cluster {k}')
      linear_models.pop(k, 'None')
      model_score.pop(k, 'None')
  print(f'\ndone\nremoved {c} clusters\n')

  print('converting feature vectors to binary concept vectors .................')
  for i, lm in enumerate(linear_models.keys()):
    if i == 0:
      concept_vecs = linear_models[lm].predict(neighbor_vectors)[:, None]
    else:
      concept_vecs = np.concatenate((concept_vecs, linear_models[lm].predict(neighbor_vectors)[:, None]), axis = -1)
  print(f'\nconcept vector dimension is\t {concept_vecs.shape[0]}x{concept_vecs.shape[1]}')
  print(f'original dimension is\t\t {neighbor_vectors.shape[0]}x{neighbor_vectors.shape[1]}')
  print('\ndone')
  
  print('building surrogate tree .............\n')
  random_seed = 0
  train_x, val_x, train_y, val_y = train_test_split(concept_vecs, neighbor_labels, test_size=0.2, random_state=random_seed)
  for depth in depths:
    surrogate_tree = DecisionTreeClassifier(max_depth = depth)
    surrogate_tree.fit(train_x, train_y)
    train_score = surrogate_tree.score(train_x, train_y)
    test_score = surrogate_tree.score(val_x, val_y)
    train_f1score = sklearn.metrics.f1_score(train_y, surrogate_tree.predict(train_x), average='weighted')
    test_f1score = sklearn.metrics.f1_score(val_y, surrogate_tree.predict(val_x), average='weighted')
    print(f'at depth {depth}:\n\ttrain accuracy:\t{train_score}')
    print(f'\ttest accuracy:\t {test_score}')
    print(f'\ttrain f1 score:\t{train_f1score}')
    print(f'\ttest f1 score:\t {test_f1score}')
    train_accuracy[depth].append(train_score)
    test_accuracy[depth].append(test_score)
    train_f1[depth].append(train_f1score)
    test_f1[depth].append(test_f1score)
    hit[depth].append(surrogate_tree.predict(concept_vecs[0][None, :])[0] == neighbor_labels[0])
  print(f'\ndone\nfinished instance {instance_id}')
# Out:
# Streaming output truncated to the last 5000 lines.
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6333333333333333
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.5596711187205197
# 	test f1 score:	 0.5730011028398125
# at depth 10:
# 	train accuracy:	0.7375
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.707850452324685
# 	test f1 score:	 0.7102950752950753
# at depth 15:
# 	train accuracy:	0.7416666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7092413874814281
# 	test f1 score:	 0.6912881562881562
# at depth 20:
# 	train accuracy:	0.7416666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7092413874814281
# 	test f1 score:	 0.6912881562881562
#
# done
# finished instance 404
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 33
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x33
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7227043044204532
# 	test f1 score:	 0.6752777226154508
# at depth 10:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.8362494893160374
# 	test f1 score:	 0.7596348171892637
# at depth 15:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.8442748516348781
# 	test f1 score:	 0.7596348171892637
# at depth 20:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.8442748516348781
# 	test f1 score:	 0.7596348171892637
#
# done
# finished instance 405
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 13
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7125
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.6605077860592566
# 	test f1 score:	 0.4905741698694012
# at depth 10:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7307259060452652
# 	test f1 score:	 0.6038076956029269
# at depth 15:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.65
# 	train f1 score:	0.7325171628984486
# 	test f1 score:	 0.5789635124717584
# at depth 20:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.65
# 	train f1 score:	0.7325171628984486
# 	test f1 score:	 0.5789635124717584
#
# done
# finished instance 406
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.65
# 	test accuracy:	 0.5666666666666667
# 	train f1 score:	0.6050058936177781
# 	test f1 score:	 0.5323742325212913
# at depth 10:
# 	train accuracy:	0.7291666666666666
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.7063438497164081
# 	test f1 score:	 0.6043217893217894
# at depth 15:
# 	train accuracy:	0.7291666666666666
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.7063438497164081
# 	test f1 score:	 0.5809701409701411
# at depth 20:
# 	train accuracy:	0.7291666666666666
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.7063438497164081
# 	test f1 score:	 0.6043217893217894
#
# done
# finished instance 407
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7
# 	test accuracy:	 0.5333333333333333
# 	train f1 score:	0.6753454268528967
# 	test f1 score:	 0.5029566996360165
# at depth 10:
# 	train accuracy:	0.8208333333333333
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.8189360026505473
# 	test f1 score:	 0.6141905237857263
# at depth 15:
# 	train accuracy:	0.8416666666666667
# 	test accuracy:	 0.65
# 	train f1 score:	0.8374616605479042
# 	test f1 score:	 0.6501164497116522
# at depth 20:
# 	train accuracy:	0.8416666666666667
# 	test accuracy:	 0.65
# 	train f1 score:	0.8374616605479042
# 	test f1 score:	 0.6471005766957791
#
# done
# finished instance 408
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.8
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.772486618081451
# 	test f1 score:	 0.6399766899766899
# at depth 10:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.7
# 	train f1 score:	0.8508369350832223
# 	test f1 score:	 0.6817777777777778
# at depth 15:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.7
# 	train f1 score:	0.8508369350832223
# 	test f1 score:	 0.6830911680911681
# at depth 20:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.7
# 	train f1 score:	0.8508369350832223
# 	test f1 score:	 0.6830911680911681
#
# done
# finished instance 409
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7666666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.735307481019226
# 	test f1 score:	 0.7088441199323552
# at depth 10:
# 	train accuracy:	0.8375
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.830098714055301
# 	test f1 score:	 0.7242136714334857
# at depth 15:
# 	train accuracy:	0.8375
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.830098714055301
# 	test f1 score:	 0.7242136714334857
# at depth 20:
# 	train accuracy:	0.8375
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.830098714055301
# 	test f1 score:	 0.7242136714334857
#
# done
# finished instance 410
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7166666666666667
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.66541198321943
# 	test f1 score:	 0.49851635079895945
# at depth 10:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.65
# 	train f1 score:	0.7764017663347035
# 	test f1 score:	 0.6226095783065092
# at depth 15:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.65
# 	train f1 score:	0.7764017663347035
# 	test f1 score:	 0.6226095783065092
# at depth 20:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.65
# 	train f1 score:	0.7764017663347035
# 	test f1 score:	 0.6226095783065092
#
# done
# finished instance 411
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 5
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7833333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7409935083508797
# 	test f1 score:	 0.674377836334358
# at depth 10:
# 	train accuracy:	0.8666666666666667
# 	test accuracy:	 0.7
# 	train f1 score:	0.863565771563579
# 	test f1 score:	 0.698252295208817
# at depth 15:
# 	train accuracy:	0.8666666666666667
# 	test accuracy:	 0.7
# 	train f1 score:	0.863565771563579
# 	test f1 score:	 0.698252295208817
# at depth 20:
# 	train accuracy:	0.8666666666666667
# 	test accuracy:	 0.7
# 	train f1 score:	0.863565771563579
# 	test f1 score:	 0.698252295208817
#
# done
# finished instance 412
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6625
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.6138869378723645
# 	test f1 score:	 0.5256781262460776
# at depth 10:
# 	train accuracy:	0.7625
# 	test accuracy:	 0.6
# 	train f1 score:	0.7364642696221946
# 	test f1 score:	 0.5734615384615385
# at depth 15:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.5666666666666667
# 	train f1 score:	0.749507088459131
# 	test f1 score:	 0.5525919732441472
# at depth 20:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.5666666666666667
# 	train f1 score:	0.749507088459131
# 	test f1 score:	 0.5525919732441472
#
# done
# finished instance 413
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7416666666666667
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.6797095675540559
# 	test f1 score:	 0.5839168358523197
# at depth 10:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7627539859102707
# 	test f1 score:	 0.6476641995996835
# at depth 15:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7630086155399003
# 	test f1 score:	 0.6393308662663502
# at depth 20:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7630086155399003
# 	test f1 score:	 0.6393308662663502
#
# done
# finished instance 414
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 31
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x31
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7583333333333333
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.7310737631251633
# 	test f1 score:	 0.5790682054384414
# at depth 10:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8419561790269297
# 	test f1 score:	 0.6592220524573466
# at depth 15:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.8419561790269297
# 	test f1 score:	 0.6353242509124862
# at depth 20:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8419561790269297
# 	test f1 score:	 0.663102028690264
#
# done
# finished instance 415
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7666666666666667
# 	test accuracy:	 0.65
# 	train f1 score:	0.7391543494301606
# 	test f1 score:	 0.6132363006663162
# at depth 10:
# 	train accuracy:	0.8416666666666667
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8345122741736953
# 	test f1 score:	 0.66590502524427
# at depth 15:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.8385031548257539
# 	test f1 score:	 0.674977274833761
# at depth 20:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.8385031548257539
# 	test f1 score:	 0.674977274833761
#
# done
# finished instance 416
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 31
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x31
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.75
# 	test accuracy:	 0.7
# 	train f1 score:	0.7083700816837832
# 	test f1 score:	 0.6986601648670614
# at depth 10:
# 	train accuracy:	0.8708333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.863468699273597
# 	test f1 score:	 0.6818148148148148
# at depth 15:
# 	train accuracy:	0.8708333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.863468699273597
# 	test f1 score:	 0.6818148148148148
# at depth 20:
# 	train accuracy:	0.8708333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.863468699273597
# 	test f1 score:	 0.6818148148148148
#
# done
# finished instance 417
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.6683980674659978
# 	test f1 score:	 0.6721717711301045
# at depth 10:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.7757643660877719
# 	test f1 score:	 0.7371236179210318
# at depth 15:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7801958991840141
# 	test f1 score:	 0.7255921065709721
# at depth 20:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7801958991840141
# 	test f1 score:	 0.7255921065709721
#
# done
# finished instance 418
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7541666666666667
# 	test accuracy:	 0.55
# 	train f1 score:	0.742142420555607
# 	test f1 score:	 0.5341991341991342
# at depth 10:
# 	train accuracy:	0.875
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.8698746969185064
# 	test f1 score:	 0.6073051948051947
# at depth 15:
# 	train accuracy:	0.875
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.8698746969185064
# 	test f1 score:	 0.6073051948051947
# at depth 20:
# 	train accuracy:	0.875
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.8698746969185064
# 	test f1 score:	 0.6047799422799421
#
# done
# finished instance 419
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 38
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6958333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.6443253695258384
# 	test f1 score:	 0.6161111111111112
# at depth 10:
# 	train accuracy:	0.7791666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.7406504931472487
# 	test f1 score:	 0.7447557997557998
# at depth 15:
# 	train accuracy:	0.7791666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.7406504931472487
# 	test f1 score:	 0.7458669108669108
# at depth 20:
# 	train accuracy:	0.7791666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.7406504931472487
# 	test f1 score:	 0.7447557997557998
#
# done
# finished instance 420
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6833333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.6362625173080189
# 	test f1 score:	 0.5747183615604669
# at depth 10:
# 	train accuracy:	0.8
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.787594579848958
# 	test f1 score:	 0.6843377260355188
# at depth 15:
# 	train accuracy:	0.8083333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.7955560870896878
# 	test f1 score:	 0.6605282022259951
# at depth 20:
# 	train accuracy:	0.8083333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.7955560870896878
# 	test f1 score:	 0.6605282022259951
#
# done
# finished instance 421
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7291666666666666
# 	test accuracy:	 0.7
# 	train f1 score:	0.7029771817516394
# 	test f1 score:	 0.6787393162393162
# at depth 10:
# 	train accuracy:	0.8083333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.7925442301991539
# 	test f1 score:	 0.7247122507122506
# at depth 15:
# 	train accuracy:	0.8208333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.8100968165017401
# 	test f1 score:	 0.7139430199430199
# at depth 20:
# 	train accuracy:	0.8208333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.8100968165017401
# 	test f1 score:	 0.7135726495726494
#
# done
# finished instance 422
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7083333333333334
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.6470518412066818
# 	test f1 score:	 0.5599494641161308
# at depth 10:
# 	train accuracy:	0.8541666666666666
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.8431674999218999
# 	test f1 score:	 0.6415669515669516
# at depth 15:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.6
# 	train f1 score:	0.8483267838640784
# 	test f1 score:	 0.5785327635327635
# at depth 20:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.8483267838640784
# 	test f1 score:	 0.6191893291893292
#
# done
# finished instance 423
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 35
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6958333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.6882271757722259
# 	test f1 score:	 0.7484046101105992
# at depth 10:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7959529571612358
# 	test f1 score:	 0.7152684742158427
# at depth 15:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7981581228532437
# 	test f1 score:	 0.7152684742158427
# at depth 20:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7981581228532437
# 	test f1 score:	 0.7152684742158427
#
# done
# finished instance 424
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7541666666666667
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.7301340418082689
# 	test f1 score:	 0.5596969696969697
# at depth 10:
# 	train accuracy:	0.8416666666666667
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.8258013275463696
# 	test f1 score:	 0.6191846062434297
# at depth 15:
# 	train accuracy:	0.85
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.8371072116466939
# 	test f1 score:	 0.6007625707625708
# at depth 20:
# 	train accuracy:	0.85
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.8371072116466939
# 	test f1 score:	 0.5752680652680653
#
# done
# finished instance 425
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.725
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7016377280379555
# 	test f1 score:	 0.6476456876456875
# at depth 10:
# 	train accuracy:	0.8458333333333333
# 	test accuracy:	 0.8166666666666667
# 	train f1 score:	0.842026825408452
# 	test f1 score:	 0.809062049062049
# at depth 15:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.8
# 	train f1 score:	0.858592242145575
# 	test f1 score:	 0.7930126663459997
# at depth 20:
# 	train accuracy:	0.8625
# 	test accuracy:	 0.8
# 	train f1 score:	0.858592242145575
# 	test f1 score:	 0.7930126663459997
#
# done
# finished instance 426
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7375
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7326093743392795
# 	test f1 score:	 0.6884767025089606
# at depth 10:
# 	train accuracy:	0.8666666666666667
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8627016143876802
# 	test f1 score:	 0.6999449564772146
# at depth 15:
# 	train accuracy:	0.875
# 	test accuracy:	 0.7
# 	train f1 score:	0.8719142375133468
# 	test f1 score:	 0.7248893065998329
# at depth 20:
# 	train accuracy:	0.875
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8719142375133468
# 	test f1 score:	 0.7111361977741288
#
# done
# finished instance 427
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 31
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x31
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.675
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.6021964064334234
# 	test f1 score:	 0.6740039045921399
# at depth 10:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.761135891150025
# 	test f1 score:	 0.7473150863473444
# at depth 15:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.761135891150025
# 	test f1 score:	 0.7473150863473444
# at depth 20:
# 	train accuracy:	0.7916666666666666
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.761135891150025
# 	test f1 score:	 0.7445373085695667
#
# done
# finished instance 428
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 21
# removed cluster 34
#
# done
# removed 2 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x26
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.725
# 	test accuracy:	 0.7
# 	train f1 score:	0.66876352495937
# 	test f1 score:	 0.6428669965512072
# at depth 10:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.7912256551861748
# 	test f1 score:	 0.741611111111111
# at depth 15:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.7912256551861748
# 	test f1 score:	 0.741611111111111
# at depth 20:
# 	train accuracy:	0.7958333333333333
# 	test accuracy:	 0.75
# 	train f1 score:	0.7912256551861748
# 	test f1 score:	 0.741611111111111
#
# done
# finished instance 429
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7
# 	test accuracy:	 0.7
# 	train f1 score:	0.6667602934836055
# 	test f1 score:	 0.6944885361552029
# at depth 10:
# 	train accuracy:	0.7833333333333333
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7638637375137043
# 	test f1 score:	 0.7191133407655147
# at depth 15:
# 	train accuracy:	0.7875
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7677526264025931
# 	test f1 score:	 0.7191133407655147
# at depth 20:
# 	train accuracy:	0.7875
# 	test accuracy:	 0.7
# 	train f1 score:	0.7677526264025931
# 	test f1 score:	 0.7009082125603866
#
# done
# finished instance 430
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7125
# 	test accuracy:	 0.75
# 	train f1 score:	0.6671107570492888
# 	test f1 score:	 0.6785050505050505
# at depth 10:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7833333333333333
# 	train f1 score:	0.7484514086941493
# 	test f1 score:	 0.761015873015873
# at depth 15:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7833333333333333
# 	train f1 score:	0.7484514086941493
# 	test f1 score:	 0.761015873015873
# at depth 20:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7833333333333333
# 	train f1 score:	0.7484514086941493
# 	test f1 score:	 0.761015873015873
#
# done
# finished instance 431
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 31
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 1
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7083333333333334
# 	test accuracy:	 0.7
# 	train f1 score:	0.6610110735618334
# 	test f1 score:	 0.6712616027938608
# at depth 10:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7953273772157953
# 	test f1 score:	 0.7076603792121035
# at depth 15:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7953273772157953
# 	test f1 score:	 0.7075071225071224
# at depth 20:
# 	train accuracy:	0.8166666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7953273772157953
# 	test f1 score:	 0.7076603792121035
#
# done
# finished instance 432
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 29
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x29
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6958333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.6623711696172209
# 	test f1 score:	 0.5711616161616162
# at depth 10:
# 	train accuracy:	0.8541666666666666
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.8530311640391446
# 	test f1 score:	 0.655660800552105
# at depth 15:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.8576397630822349
# 	test f1 score:	 0.6230555555555556
# at depth 20:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.8576397630822349
# 	test f1 score:	 0.68324016563147
#
# done
# finished instance 433
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6833333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.6627561603350699
# 	test f1 score:	 0.6646423000620901
# at depth 10:
# 	train accuracy:	0.7833333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7686352029533522
# 	test f1 score:	 0.7149958354156254
# at depth 15:
# 	train accuracy:	0.7833333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7686352029533522
# 	test f1 score:	 0.7149958354156254
# at depth 20:
# 	train accuracy:	0.7833333333333333
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7686352029533522
# 	test f1 score:	 0.7149958354156254
#
# done
# finished instance 434
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x28
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.6493007229294357
# 	test f1 score:	 0.6761111111111112
# at depth 10:
# 	train accuracy:	0.7666666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.7414712228639727
# 	test f1 score:	 0.7511436781609196
# at depth 15:
# 	train accuracy:	0.7666666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.7436994096684642
# 	test f1 score:	 0.7559065934065933
# at depth 20:
# 	train accuracy:	0.7666666666666667
# 	test accuracy:	 0.7833333333333333
# 	train f1 score:	0.7436994096684642
# 	test f1 score:	 0.7742142857142856
#
# done
# finished instance 435
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6916666666666667
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.6438714732094424
# 	test f1 score:	 0.5362698412698413
# at depth 10:
# 	train accuracy:	0.8
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7809801574259745
# 	test f1 score:	 0.7033333333333333
# at depth 15:
# 	train accuracy:	0.8041666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7847392153969891
# 	test f1 score:	 0.7033333333333333
# at depth 20:
# 	train accuracy:	0.8041666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.7847392153969891
# 	test f1 score:	 0.7033333333333333
#
# done
# finished instance 436
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 38
# total number of good clusters is 33
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x33
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6833333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.6473128222107246
# 	test f1 score:	 0.6499112364243943
# at depth 10:
# 	train accuracy:	0.775
# 	test accuracy:	 0.7
# 	train f1 score:	0.7677391227583431
# 	test f1 score:	 0.692686609199767
# at depth 15:
# 	train accuracy:	0.775
# 	test accuracy:	 0.7
# 	train f1 score:	0.7677391227583431
# 	test f1 score:	 0.692686609199767
# at depth 20:
# 	train accuracy:	0.775
# 	test accuracy:	 0.7
# 	train f1 score:	0.7677391227583431
# 	test f1 score:	 0.7000675615807194
#
# done
# finished instance 437
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6291666666666667
# 	test accuracy:	 0.6
# 	train f1 score:	0.5641200710809334
# 	test f1 score:	 0.5338730490454628
# at depth 10:
# 	train accuracy:	0.7625
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.7354456658511306
# 	test f1 score:	 0.6157712657712657
# at depth 15:
# 	train accuracy:	0.7625
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.7354456658511306
# 	test f1 score:	 0.6157712657712657
# at depth 20:
# 	train accuracy:	0.7625
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.7354456658511306
# 	test f1 score:	 0.6157712657712657
#
# done
# finished instance 438
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 30
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x30
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.675
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.6181321031797863
# 	test f1 score:	 0.548782151396167
# at depth 10:
# 	train accuracy:	0.7583333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.7329269527168234
# 	test f1 score:	 0.6237200092372505
# at depth 15:
# 	train accuracy:	0.7583333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.7329269527168234
# 	test f1 score:	 0.6237200092372505
# at depth 20:
# 	train accuracy:	0.7583333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.7329269527168234
# 	test f1 score:	 0.6149880005052419
#
# done
# finished instance 439
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 26
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x26
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.725
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.6967533869397223
# 	test f1 score:	 0.6433201058201058
# at depth 10:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7550972008911363
# 	test f1 score:	 0.6805698005698005
# at depth 15:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7550972008911363
# 	test f1 score:	 0.6805698005698005
# at depth 20:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.7550972008911363
# 	test f1 score:	 0.6805698005698005
#
# done
# finished instance 440
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 38
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6958333333333333
# 	test accuracy:	 0.65
# 	train f1 score:	0.6281786263891707
# 	test f1 score:	 0.5897906838369671
# at depth 10:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7
# 	train f1 score:	0.7346139401675451
# 	test f1 score:	 0.6592577030812325
# at depth 15:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7
# 	train f1 score:	0.7346139401675451
# 	test f1 score:	 0.6642784992784992
# at depth 20:
# 	train accuracy:	0.7708333333333334
# 	test accuracy:	 0.7
# 	train f1 score:	0.7346139401675451
# 	test f1 score:	 0.6642784992784992
#
# done
# finished instance 441
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 36
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7166666666666667
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.6586989593120722
# 	test f1 score:	 0.5441308243727598
# at depth 10:
# 	train accuracy:	0.8041666666666667
# 	test accuracy:	 0.6
# 	train f1 score:	0.7738262510300042
# 	test f1 score:	 0.5670112414467253
# at depth 15:
# 	train accuracy:	0.8041666666666667
# 	test accuracy:	 0.6
# 	train f1 score:	0.7738262510300042
# 	test f1 score:	 0.5670112414467253
# at depth 20:
# 	train accuracy:	0.8041666666666667
# 	test accuracy:	 0.6
# 	train f1 score:	0.7738262510300042
# 	test f1 score:	 0.5670112414467253
#
# done
# finished instance 442
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 28
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 9
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6916666666666667
# 	test accuracy:	 0.55
# 	train f1 score:	0.6383582694007514
# 	test f1 score:	 0.4773910256410256
# at depth 10:
# 	train accuracy:	0.725
# 	test accuracy:	 0.6
# 	train f1 score:	0.6801639919178271
# 	test f1 score:	 0.5225025472611678
# at depth 15:
# 	train accuracy:	0.725
# 	test accuracy:	 0.6
# 	train f1 score:	0.6801639919178271
# 	test f1 score:	 0.5225025472611678
# at depth 20:
# 	train accuracy:	0.725
# 	test accuracy:	 0.6
# 	train f1 score:	0.6801639919178271
# 	test f1 score:	 0.5225025472611678
#
# done
# finished instance 443
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 37
# total number of good clusters is 27
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x27
# ...
# 	test f1 score:	 0.45791493985508436
# at depth 10:
# 	train accuracy:	0.8875
# 	test accuracy:	 0.6
# 	train f1 score:	0.8818130509054277
# 	test f1 score:	 0.5980262301624532
# at depth 15:
# 	train accuracy:	0.9375
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.9360658848612218
# 	test f1 score:	 0.5704304954304954
# at depth 20:
# 	train accuracy:	0.9375
# 	test accuracy:	 0.5666666666666667
# 	train f1 score:	0.9373809663502551
# 	test f1 score:	 0.5634463684463685
#
# done
# finished instance 486
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 53
# total number of good clusters is 40
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x40
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.625
# 	test accuracy:	 0.43333333333333335
# 	train f1 score:	0.6094198574361788
# 	test f1 score:	 0.4186111111111111
# at depth 10:
# 	train accuracy:	0.9375
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.9344477997706743
# 	test f1 score:	 0.5617834790432045
# at depth 15:
# 	train accuracy:	0.95
# 	test accuracy:	 0.6
# 	train f1 score:	0.9470143844934084
# 	test f1 score:	 0.573063599278433
# at depth 20:
# 	train accuracy:	0.95
# 	test accuracy:	 0.6
# 	train f1 score:	0.9470143844934084
# 	test f1 score:	 0.5770995469908513
#
# done
# finished instance 487
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 56
# total number of good clusters is 44
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x44
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7375
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.7103609225946319
# 	test f1 score:	 0.60549792484777
# at depth 10:
# 	train accuracy:	0.925
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.9235146042216231
# 	test f1 score:	 0.7753113553113554
# at depth 15:
# 	train accuracy:	0.95
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9489281941865383
# 	test f1 score:	 0.764063159063159
# at depth 20:
# 	train accuracy:	0.95
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9489281941865383
# 	test f1 score:	 0.7502216382651166
#
# done
# finished instance 488
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 44
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 21
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x43
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6875
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.6678059067680067
# 	test f1 score:	 0.5590162494510321
# at depth 10:
# 	train accuracy:	0.925
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.92109656844547
# 	test f1 score:	 0.7351655207537561
# at depth 15:
# 	train accuracy:	0.9541666666666667
# 	test accuracy:	 0.75
# 	train f1 score:	0.95466833442362
# 	test f1 score:	 0.755172735760971
# at depth 20:
# 	train accuracy:	0.9541666666666667
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.95466833442362
# 	test f1 score:	 0.7671869667407194
#
# done
# finished instance 489
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 55
# total number of good clusters is 50
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x50
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6041666666666666
# 	test accuracy:	 0.5666666666666667
# 	train f1 score:	0.5889981568425754
# 	test f1 score:	 0.5265445665445666
# at depth 10:
# 	train accuracy:	0.8791666666666667
# 	test accuracy:	 0.6
# 	train f1 score:	0.8800030625371058
# 	test f1 score:	 0.5903505535858476
# at depth 15:
# 	train accuracy:	0.9583333333333334
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.9587765812444324
# 	test f1 score:	 0.6702272727272728
# at depth 20:
# 	train accuracy:	0.9625
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.9628385008737176
# 	test f1 score:	 0.6518892218892219
#
# done
# finished instance 490
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 41
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x41
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6625
# 	test accuracy:	 0.65
# 	train f1 score:	0.633496430998293
# 	test f1 score:	 0.6295629169542213
# at depth 10:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.8553626736691945
# 	test f1 score:	 0.6921694318753142
# at depth 15:
# 	train accuracy:	0.925
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.924621238550758
# 	test f1 score:	 0.6733232780291604
# at depth 20:
# 	train accuracy:	0.925
# 	test accuracy:	 0.7
# 	train f1 score:	0.924621238550758
# 	test f1 score:	 0.6951486748545572
#
# done
# finished instance 491
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 41
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
# removed cluster 9
#
# done
# removed 1 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x40
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7375
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.7228699377364816
# 	test f1 score:	 0.66875
# at depth 10:
# 	train accuracy:	0.8958333333333334
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.8927890110444031
# 	test f1 score:	 0.7341910365375839
# at depth 15:
# 	train accuracy:	0.9083333333333333
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.9071087541746299
# 	test f1 score:	 0.7476672553079203
# at depth 20:
# 	train accuracy:	0.9083333333333333
# 	test accuracy:	 0.7666666666666667
# 	train f1 score:	0.9071087541746299
# 	test f1 score:	 0.7476672553079203
#
# done
# finished instance 492
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 48
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x48
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7
# 	test accuracy:	 0.5833333333333334
# 	train f1 score:	0.6635728968835625
# 	test f1 score:	 0.5291880341880343
# at depth 10:
# 	train accuracy:	0.9125
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.914117975949869
# 	test f1 score:	 0.5955555555555556
# at depth 15:
# 	train accuracy:	0.9583333333333334
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9589991196542049
# 	test f1 score:	 0.6893210955710956
# at depth 20:
# 	train accuracy:	0.9583333333333334
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.9589991196542049
# 	test f1 score:	 0.6755176767676768
#
# done
# finished instance 493
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 44
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x44
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6916666666666667
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.6732147302910981
# 	test f1 score:	 0.6126952798663325
# at depth 10:
# 	train accuracy:	0.8916666666666667
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.8901902005406103
# 	test f1 score:	 0.6318696581196581
# at depth 15:
# 	train accuracy:	0.9666666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9665610682240667
# 	test f1 score:	 0.7331762870772158
# at depth 20:
# 	train accuracy:	0.9666666666666667
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.9665610682240667
# 	test f1 score:	 0.7208029878618113
#
# done
# finished instance 494
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 53
# total number of good clusters is 45
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x45
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.7041666666666667
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.6803863619028581
# 	test f1 score:	 0.5638982995561943
# at depth 10:
# 	train accuracy:	0.9333333333333333
# 	test accuracy:	 0.7
# 	train f1 score:	0.9322720012664701
# 	test f1 score:	 0.6599494949494951
# at depth 15:
# 	train accuracy:	0.9666666666666667
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.9666767827816294
# 	test f1 score:	 0.6320634920634921
# at depth 20:
# 	train accuracy:	0.9666666666666667
# 	test accuracy:	 0.65
# 	train f1 score:	0.9666767827816294
# 	test f1 score:	 0.626355150697256
#
# done
# finished instance 495
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 53
# total number of good clusters is 45
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x45
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6708333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.6512627536586295
# 	test f1 score:	 0.6604891676950501
# at depth 10:
# 	train accuracy:	0.95
# 	test accuracy:	 0.65
# 	train f1 score:	0.9461039928818598
# 	test f1 score:	 0.651388018112156
# at depth 15:
# 	train accuracy:	0.9583333333333334
# 	test accuracy:	 0.6166666666666667
# 	train f1 score:	0.9565141181464992
# 	test f1 score:	 0.6196608946608947
# at depth 20:
# 	train accuracy:	0.9583333333333334
# 	test accuracy:	 0.6333333333333333
# 	train f1 score:	0.9565141181464992
# 	test f1 score:	 0.6364502164502164
#
# done
# finished instance 496
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 44
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x44
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6458333333333334
# 	test accuracy:	 0.5333333333333333
# 	train f1 score:	0.6213292964379743
# 	test f1 score:	 0.5027247631595457
# at depth 10:
# 	train accuracy:	0.8583333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.8525774050060086
# 	test f1 score:	 0.6447202431697316
# at depth 15:
# 	train accuracy:	0.9083333333333333
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.9065048480538404
# 	test f1 score:	 0.6707951362363127
# at depth 20:
# 	train accuracy:	0.9083333333333333
# 	test accuracy:	 0.6833333333333333
# 	train f1 score:	0.9065048480538404
# 	test f1 score:	 0.6814309056956116
#
# done
# finished instance 497
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 54
# total number of good clusters is 46
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x46
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6
# 	test accuracy:	 0.5333333333333333
# 	train f1 score:	0.547870956061489
# 	test f1 score:	 0.5139213184476341
# at depth 10:
# 	train accuracy:	0.9125
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.9116408944228278
# 	test f1 score:	 0.7325873015873016
# at depth 15:
# 	train accuracy:	0.975
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.9742747260380246
# 	test f1 score:	 0.7185482938114517
# at depth 20:
# 	train accuracy:	0.975
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9742747260380246
# 	test f1 score:	 0.735958485958486
#
# done
# finished instance 498
# clustering the neighbor dataset ................
#
# done
# removing small clusters  ................
#
# total number of clusters 55
# total number of good clusters is 42
#
# done
# removing single image clusters ............
#
# done
# building linear models for each concept/cluster ............
#
# done
# removing low scoring clusters based on holdout accuracy ...............
#
#
# done
# removed 0 clusters
#
# converting feature vectors to binary concept vectors .................
#
# concept vector dimension is	 300x42
# original dimension is		 300x2048
#
# done
# building surrogate tree .............
#
# at depth 5:
# 	train accuracy:	0.6791666666666667
# 	test accuracy:	 0.6666666666666666
# 	train f1 score:	0.660192518325887
# 	test f1 score:	 0.634910439271494
# at depth 10:
# 	train accuracy:	0.9
# 	test accuracy:	 0.7166666666666667
# 	train f1 score:	0.8979847814923133
# 	test f1 score:	 0.7125940725940725
# at depth 15:
# 	train accuracy:	0.9416666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9394678181678288
# 	test f1 score:	 0.7212063492063492
# at depth 20:
# 	train accuracy:	0.9416666666666667
# 	test accuracy:	 0.7333333333333333
# 	train f1 score:	0.9394678181678288
# 	test f1 score:	 0.7212063492063492
#
# done
# finished instance 499

# %%
with open('train_accuracies.pkl', 'wb') as f:
  pickle.dump(train_accuracy, f)
with open('test_accuracies.pkl', 'wb') as f:
  pickle.dump(test_accuracy, f)
with open('train_f1.pkl', 'wb') as f:
  pickle.dump(train_f1, f)
with open('test_f1.pkl', 'wb') as f:
  pickle.dump(test_f1, f)
with open('hit.pkl', 'wb') as f:
  pickle.dump(hit, f)

# %%
# !cp train_accuracies.pkl drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/local_train_accuracies_depth_acc.pkl
# !cp test_accuracies.pkl drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/local_test_accuracies_depth_acc.pkl
# !cp train_f1.pkl drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/local_train_f1_depth_acc.pkl
# !cp test_f1.pkl drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/local_test_f1_depth_acc.pkl
# !cp hit.pkl drive/'My Drive'/'Colab Notebooks'/'Automate local TCAV'/'final notebooks'/local_hit_depth_acc.pkl
